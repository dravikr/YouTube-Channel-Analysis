# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Channel Metadata

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime, timedelta

# %%
api_key = 'AIzaSyBajnJT4G686q0v92lmNpTHVHEb41Ouvcc'

# %%
channel_id = 'UC7cs8q-gJRlGwj4A8OmCmXg'

# %%
youtube = build("youtube", "v3", developerKey=api_key)

# %%
def get_channel_metadata(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()
    item = response['items'][0]

    metadata = {
        "Channel_name": item["snippet"]["title"],
        "Subscribers": item["statistics"]["subscriberCount"],
        "Views": item["statistics"]["viewCount"],
        "PublishedAt": item["snippet"]["publishedAt"],
        "Country": item.get("snippet", {}).get("country", "N/A"),
        "Total_videos": item["statistics"]["videoCount"],
        "playlist_id": item["contentDetails"]["relatedPlaylists"]["uploads"]
    }
    return metadata

# %%
channel_metadata = get_channel_metadata(youtube, channel_id)
channel_df = pd.DataFrame([channel_metadata])

# %%
channel_df
# Out:
#        Channel_name Subscribers     Views                  PublishedAt  \
# 0  Alex The Analyst     1130000  53403017  2020-01-08T05:04:24.970712Z
#
#   Country Total_videos               playlist_id
# 0      US          386  UU7cs8q-gJRlGwj4A8OmCmXg

# %%
channel_df.to_csv("metadata.csv", index=False)

# %% [markdown]
# # Videos Data

# %%
pip install isodate
# Out:
# Collecting isodate
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate
# Successfully installed isodate-0.7.2

# %%
from datetime import datetime, timedelta
import isodate

# %%
def get_all_videos_with_stats(youtube, playlist_id):
    videos = []
    next_page_token = None

    while True:
        request = youtube.playlistItems().list(
            part="snippet",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            published_at = item["snippet"]["publishedAt"]
            video_id = item["snippet"]["resourceId"]["videoId"]
            video_title = item["snippet"]["title"]

            stats_response = youtube.videos().list(
                part="statistics,contentDetails",
                id=video_id
            ).execute()

            video_data = stats_response['items'][0]
            stats = video_data['statistics']
            duration_iso = video_data['contentDetails']['duration']
            duration_seconds = isodate.parse_duration(duration_iso).total_seconds()

            videos.append({
                "video_id": video_id,
                "video_title": video_title,
                "published_at": published_at,
                "view_count": int(stats.get("viewCount", 0)),
                "like_count": int(stats.get("likeCount", 0)),
                "comment_count": int(stats.get("commentCount", 0)),
                "duration_seconds": duration_seconds
            })

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return pd.DataFrame(videos)

# %%
playlist_id = channel_df["playlist_id"].iloc[0]
df_videos = get_all_videos_with_stats(youtube, playlist_id)

# %%
df_videos.head(5)
# Out:
#       video_id                                        video_title  \
# 0  kk5zEOQzTmQ  Data Visualization and Presentation in R | R f...
# 1  yhlqKsYpzgE  Alex The Analyst Q/A Livestream | Come Ask Me ...
# 2  TP2OJuZhbIQ              Things I Learned as a Data Analyst p1
# 3  Mi8st3hyMH8  Alex The Analyst Q/A Livestream | Come Ask Me ...
# 4  vAKs1-EEJ38  How to Remove Duplicates in an R Dataframe | R...
#
#            published_at  view_count  like_count  comment_count  \
# 0  2025-08-19T12:01:22Z        1860          61              5
# 1  2025-08-18T01:01:35Z           0           8              0
# 2  2025-08-15T11:46:04Z        5823         203             12
# 3  2025-08-14T14:18:24Z        2777         109              8
# 4  2025-08-12T12:01:49Z        1752          59              2
#
#    duration_seconds
# 0            1264.0
# 1               0.0
# 2              38.0
# 3            3967.0
# 4             488.0

# %%
df_videos.to_csv("videos.csv", index=False)

# %%
from googleapiclient.errors import HttpError
import pandas as pd
import time

def get_video_comments(youtube, video_id, max_comments=100):
    """
    Fetch up to `max_comments` for a given video_id.
    Returns a list of dictionaries with video_id and comment text.
    Skips videos with comments disabled.
    """
    comments = []
    next_page_token = None
    count = 0

    while True:
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=100,  # API max per page is 100
                pageToken=next_page_token,
                textFormat="plainText"
            )
            response = request.execute()

            for item in response['items']:
                comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay']
                comments.append({
                    "video_id": video_id,
                    "comment": comment_text
                })
                count += 1
                if count >= max_comments:
                    break

            next_page_token = response.get("nextPageToken")
            if not next_page_token or count >= max_comments:
                break

        except HttpError as e:
            if e.resp.status in [403, 404]:
                print(f"Skipping video {video_id} (comments disabled or unavailable)")
                break
            else:
                print(f"Error for video {video_id}: {e}")
                time.sleep(5)  # wait a bit before retrying
                continue

    return comments

all_comments = []

for idx, row in df_videos.iterrows():
    vid = row['video_id']
    print(f"Fetching comments for video {vid} ({idx+1}/{len(df_videos)})")
    video_comments = get_video_comments(youtube, vid, max_comments=100)
    all_comments.extend(video_comments)

# Convert to DataFrame
df_comments = pd.DataFrame(all_comments)

# Save to CSV
df_comments.to_csv("video_comments.csv", index=False)
print("Comments extraction completed!")
# Out:
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Fetching comments for video kk5zEOQzTmQ (1/387)
# Fetching comments for video yhlqKsYpzgE (2/387)
# Skipping video yhlqKsYpzgE (comments disabled or unavailable)
# Fetching comments for video TP2OJuZhbIQ (3/387)
# Fetching comments for video Mi8st3hyMH8 (4/387)
# Fetching comments for video vAKs1-EEJ38 (5/387)
# Fetching comments for video -Z2KjOUcvTA (6/387)
# Fetching comments for video v5jasYkmwZI (7/387)
# Fetching comments for video kqhJff8ruKw (8/387)
# Fetching comments for video QR8kxf925IQ (9/387)
# Fetching comments for video klKWFqsqFeI (10/387)
# Fetching comments for video XIWe4vCtHcY (11/387)
# Fetching comments for video PqCp1f0RIaU (12/387)
# Fetching comments for video 0B-lz9VQkYs (13/387)
# Fetching comments for video _YG8b1g-QJA (14/387)
# Fetching comments for video UT_hTGge_wc (15/387)
# Fetching comments for video A42T_b0gwF4 (16/387)
# Fetching comments for video 8NfozskpBtY (17/387)
# Fetching comments for video lpK71OwmG0s (18/387)
# Fetching comments for video QC1Jased-PA (19/387)
# Fetching comments for video O5nQKzBb0oc (20/387)
# Fetching comments for video 73S2SJSTgQU (21/387)
# Fetching comments for video TsnGd6p9oTk (22/387)
# Fetching comments for video DsI1vG-kXR8 (23/387)
# Fetching comments for video 4lhPHhPkVLM (24/387)
# Fetching comments for video dkU5n0G7FRQ (25/387)
# Fetching comments for video kagUDLvrcZ8 (26/387)
# Fetching comments for video P5uJYPjUtlc (27/387)
# Fetching comments for video dStNNjOKML4 (28/387)
# Fetching comments for video OQM9x6E3ojo (29/387)
# Fetching comments for video z39SB95JbDo (30/387)
# Fetching comments for video W5CQb7klLCs (31/387)
# Fetching comments for video xb5-UX-jYw0 (32/387)
# Fetching comments for video V3ouFOBQP0k (33/387)
# Fetching comments for video oi9W142ELN0 (34/387)
# Fetching comments for video 5n52mlp9Ym0 (35/387)
# Fetching comments for video hgp91KvbJV4 (36/387)
# Fetching comments for video 1ql4kNv0_qY (37/387)
# Fetching comments for video r5512UY3MTc (38/387)
# Fetching comments for video XuOcmjIbFGg (39/387)
# Fetching comments for video Ka2mDrKEAhg (40/387)
# Fetching comments for video k8nBWL6K884 (41/387)
# Fetching comments for video WpX2F2BS3Qc (42/387)
# Fetching comments for video cd_jj0IRmaA (43/387)
# Fetching comments for video OcG0B4ny1cE (44/387)
# Fetching comments for video hXpt8zj_ajc (45/387)
# Fetching comments for video ItZlTixh6Bs (46/387)
# Fetching comments for video PEWMgtu-1e4 (47/387)
# Fetching comments for video hCmEfxy-BXg (48/387)
# Fetching comments for video TtCBz1lutsY (49/387)
# Fetching comments for video Ihmq-qeA5Pc (50/387)
# Fetching comments for video wQQR60KtnFY (51/387)
# Fetching comments for video oHte3qFa-oY (52/387)
# Fetching comments for video P7p2OZj9ewU (53/387)
# Fetching comments for video I0vQ_VLZTWg (54/387)
# Fetching comments for video tnz72ywhCoo (55/387)
# Fetching comments for video j8FSP8XuFyk (56/387)
# Fetching comments for video zXnQNytHCPM (57/387)
# Fetching comments for video osA1QpBcxRs (58/387)
# Fetching comments for video Mdq1WWSdUtw (59/387)
# Fetching comments for video CZt2BUpgjgw (60/387)
# Fetching comments for video t1fQBD4B7xk (61/387)
# Fetching comments for video OT1RErkfLNQ (62/387)
# Fetching comments for video rxyLC247h6E (63/387)
# Fetching comments for video AycpRKyRagE (64/387)
# Fetching comments for video K2GfrERtliU (65/387)
# Fetching comments for video xmVyaT-RuVo (66/387)
# Fetching comments for video amb9bciHGSI (67/387)
# Fetching comments for video hgaVi4sOHkM (68/387)
# Fetching comments for video YSjbGET6R1A (69/387)
# Fetching comments for video vDVcXXfc9e8 (70/387)
# Fetching comments for video Vg6ys_JvXzg (71/387)
# Fetching comments for video sge9qTf8GdY (72/387)
# Fetching comments for video 9ur0OpMADuM (73/387)
# Fetching comments for video UTMuL_86gSQ (74/387)
# Fetching comments for video sEImMaovc1Q (75/387)
# Fetching comments for video ZYps6TmBkWk (76/387)
# Fetching comments for video zv1nfZTYpio (77/387)
# Fetching comments for video rn0dSsYXhIE (78/387)
# Fetching comments for video siHou7lObbo (79/387)
# Fetching comments for video wJiJXD7MVoY (80/387)
# Fetching comments for video BzwAZ1k3WEY (81/387)
# Fetching comments for video 5q2u8__sVhs (82/387)
# Fetching comments for video UJbNEH0_nGY (83/387)
# Fetching comments for video oz2K4HUNMW4 (84/387)
# Fetching comments for video Y-4ri9QjsTI (85/387)
# Fetching comments for video F5v2dRYU5IA (86/387)
# Fetching comments for video _R6K1aNtKpE (87/387)
# Fetching comments for video 5tKmTdvEAVk (88/387)
# Fetching comments for video QYd-RtK58VQ (89/387)
# Fetching comments for video c5ko0sedE7k (90/387)
# Fetching comments for video 4UltKCnnnTA (91/387)
# Fetching comments for video BV5ckMNNvi4 (92/387)
# Fetching comments for video QMUZ5HfWMRc (93/387)
# Fetching comments for video 7b8ViCqD9JM (94/387)
# Fetching comments for video 7vnxpcqmqNQ (95/387)
# Fetching comments for video uEk07jXdKOo (96/387)
# Fetching comments for video UC7uvOqcUTs (97/387)
# Fetching comments for video 1KEbiqRWOkA (98/387)
# Fetching comments for video UOBTLzWY1vs (99/387)
# Fetching comments for video 8zOkBTs0yxs (100/387)
# Fetching comments for video 7NBt0V8ebGk (101/387)
# Fetching comments for video FGC0cCAgGu0 (102/387)
# Fetching comments for video Vj6RqA_X-IE (103/387)
# Fetching comments for video RYIiOG4LsvQ (104/387)
# Fetching comments for video 5y7tLNPVJPA (105/387)
# Fetching comments for video _nf56aMPdZE (106/387)
# Fetching comments for video XbDRYzYUmMo (107/387)
# Fetching comments for video KRXSJb9ql1Y (108/387)
# Fetching comments for video iTQW_nDp938 (109/387)
# Fetching comments for video lXQzD09BOH0 (110/387)
# Fetching comments for video xtC3212t4hI (111/387)
# Fetching comments for video KZKizyBS9YM (112/387)
# Fetching comments for video I0_ca6iyo6w (113/387)
# Fetching comments for video GZS7AgQ4Ksg (114/387)
# Fetching comments for video fT-8mRf_-Hk (115/387)
# Fetching comments for video ZHaYOC0H5KE (116/387)
# Fetching comments for video K0-8G3DgjA4 (117/387)
# Fetching comments for video ZnAydTqCtFU (118/387)
# Fetching comments for video qPOmj22QX04 (119/387)
# Fetching comments for video XD1ul5fpnGI (120/387)
# Fetching comments for video kifhSqep9UM (121/387)
# Fetching comments for video dCNjUOc1cBY (122/387)
# Fetching comments for video lEjmgE-hogg (123/387)
# Fetching comments for video qxj3dx0c7RM (124/387)
# Fetching comments for video zgYqUP_PhQo (125/387)
# Fetching comments for video MARn_mssG4A (126/387)
# Fetching comments for video TGAUZQJaQbQ (127/387)
# Fetching comments for video HYD8KjPB9F8 (128/387)
# Fetching comments for video wgRwITQHszU (129/387)
# Fetching comments for video 1LG65qXfeQY (130/387)
# Fetching comments for video QzLz-W29Tww (131/387)
# Fetching comments for video ukIUVW2E-n0 (132/387)
# Fetching comments for video aofB2t5o2ao (133/387)
# Fetching comments for video -DwpkgtJjGw (134/387)
# Fetching comments for video h4KTy2wxYcQ (135/387)
# Fetching comments for video LaRXtE4OG9A (136/387)
# Fetching comments for video J0PcCv9f4JQ (137/387)
# Fetching comments for video _DGn-7134i0 (138/387)
# Fetching comments for video EflE8U30pBo (139/387)
# Fetching comments for video j_sHaBJEHMk (140/387)
# Fetching comments for video xuyKzpJ2SaY (141/387)
# Fetching comments for video D0mEy6bJ2lA (142/387)
# Fetching comments for video GaoAc3-hScQ (143/387)
# Fetching comments for video bxIF9X9k2IE (144/387)
# Fetching comments for video z_xWpa88R0A (145/387)
# Fetching comments for video 7PoZBuIUnEU (146/387)
# Fetching comments for video fq1-e-GbihE (147/387)
# Fetching comments for video Xkb6h3YXl_c (148/387)
# Fetching comments for video qDprq7Xbrqw (149/387)
# Fetching comments for video UOHxb9ndpMM (150/387)
# Fetching comments for video _h_A_n8Z9QQ (151/387)
# Fetching comments for video _oCUSMX4_3k (152/387)
# Fetching comments for video OnS01G8W6nw (153/387)
# Fetching comments for video ugkyfUTc6AU (154/387)
# Fetching comments for video eON-PNPae8Y (155/387)
# Fetching comments for video 41nX2ZgGzcE (156/387)
# Fetching comments for video Le35Qsgs2lM (157/387)
# Fetching comments for video nufF-juSZxU (158/387)
# Fetching comments for video 9NB5u17qiDY (159/387)
# Fetching comments for video YDvJqgBv0Uc (160/387)
# Fetching comments for video j6A28L6Tmxw (161/387)
# Fetching comments for video W_s4c1vLGXM (162/387)
# Fetching comments for video DWte9zjGl0I (163/387)
# Fetching comments for video EzeeypMKx7o (164/387)
# Fetching comments for video OISvlkfbntY (165/387)
# Fetching comments for video 8dTpNajxaH0 (166/387)
# Fetching comments for video oreAsJTNcsA (167/387)
# Fetching comments for video xjA1HjvmoMY (168/387)
# Fetching comments for video LO7hzmoHEIE (169/387)
# Fetching comments for video bargNl2WeN4 (170/387)
# Fetching comments for video q-kbzWjyPak (171/387)
# Fetching comments for video PExdWWcxmro (172/387)
# Fetching comments for video Liv6eeb1VfE (173/387)
# Fetching comments for video fHK4nHbUtj0 (174/387)
# Fetching comments for video 5l2d_Rv0odE (175/387)
# Fetching comments for video bDhvCp3_lYw (176/387)
# Fetching comments for video IMU1V-JugKo (177/387)
# Fetching comments for video FpgkpjSyBOw (178/387)
# Fetching comments for video 6jtS3Hz19kc (179/387)
# Fetching comments for video JpSMse3eVVg (180/387)
# Fetching comments for video TPivN7tpdwc (181/387)
# Fetching comments for video kky9MMydnOA (182/387)
# Fetching comments for video 2izXQUoXyjA (183/387)
# Fetching comments for video zilfrWwbteQ (184/387)
# Fetching comments for video PJINexERxOs (185/387)
# Fetching comments for video gTf2GLEhKgA (186/387)
# Fetching comments for video VRmXto2YA2I (187/387)
# Fetching comments for video 6yNsc7JVPJE (188/387)
# Fetching comments for video mBCG9J1TVTc (189/387)
# Fetching comments for video WizLaDdsHUs (190/387)
# Fetching comments for video kB7FV-ijdqE (191/387)
# Fetching comments for video dFA0E-6xT_M (192/387)
# Fetching comments for video dUpyC40cF6Q (193/387)
# Fetching comments for video gs0FNQR0njI (194/387)
# Fetching comments for video C75TROiiEa0 (195/387)
# Fetching comments for video rGx1QNdYzvs (196/387)
# Fetching comments for video CUBfrdDwznQ (197/387)
# Fetching comments for video L-QnW_BZT3c (198/387)
# Fetching comments for video S76iS03nGis (199/387)
# Fetching comments for video RBEgsEVO3T8 (200/387)
# Fetching comments for video gCG07l6Fu-U (201/387)
# Fetching comments for video DXwFsxCtukg (202/387)
# Fetching comments for video ey1VNjU0YbM (203/387)
# Fetching comments for video 0MKcCHrTo0c (204/387)
# Fetching comments for video bVJfQAe-UP4 (205/387)
# Fetching comments for video _2OknmkngkQ (206/387)
# Fetching comments for video B63bN2cLVLM (207/387)
# Fetching comments for video zvzjaqMBEso (208/387)
# Fetching comments for video ECduJk00mUU (209/387)
# Fetching comments for video zmIdC0_0BgY (210/387)
# Fetching comments for video eP8-mo5jRrY (211/387)
# Fetching comments for video -BOBedcjySI (212/387)
# Fetching comments for video lPVke-p4S7s (213/387)
# Fetching comments for video ppsCxnNm-JI (214/387)
# Fetching comments for video rVhHGPDzEck (215/387)
# Fetching comments for video pHOH7UfOhbE (216/387)
# Fetching comments for video sXHIIW3Wt84 (217/387)
# Fetching comments for video WUeBzT43JyY (218/387)
# Fetching comments for video DVs9u15htXU (219/387)
# Fetching comments for video zW3qJUeJLWc (220/387)
# Fetching comments for video m1AkWK_ODLM (221/387)
# Fetching comments for video Pfq-8pGzgg4 (222/387)
# Fetching comments for video pixlHHe_lNQ (223/387)
# Fetching comments for video 3NV5Jtbhfcw (224/387)
# Fetching comments for video 1cfrQLoJMPI (225/387)
# Fetching comments for video 9j_EBt3RNrs (226/387)
# Fetching comments for video m0h3Ghl6mgY (227/387)
# Fetching comments for video 50D__p6jdEI (228/387)
# Fetching comments for video tRCGGlMI19M (229/387)
# Fetching comments for video 0QZBnhofU_U (230/387)
# Fetching comments for video ulFY20KTzFQ (231/387)
# Fetching comments for video PEc29sRZoTM (232/387)
# Fetching comments for video DlEkWd-8VXA (233/387)
# Fetching comments for video vcijg0gUXSg (234/387)
# Fetching comments for video gCg47n_TlFc (235/387)
# Fetching comments for video sW5LoDA1ssM (236/387)
# Fetching comments for video 4nsdARJGzJ0 (237/387)
# Fetching comments for video _QvQxm4dptI (238/387)
# Fetching comments for video HX2TabgkzHo (239/387)
# Fetching comments for video gP-AxNi6uxo (240/387)
# Fetching comments for video KB2CtEDrglY (241/387)
# Fetching comments for video 2HfSFdPEFRg (242/387)
# Fetching comments for video g0m5sEHPU-s (243/387)
# Fetching comments for video Q7i6zxHVj2Q (244/387)
# Fetching comments for video ddn-2r1j_OU (245/387)
# Fetching comments for video Pf-9pjJK1e0 (246/387)
# Fetching comments for video -bSkREem8dM (247/387)
# Fetching comments for video xKdtP3IZbnU (248/387)
# Fetching comments for video GsAXOr715AU (249/387)
# Fetching comments for video 2JnlQ8jwWbE (250/387)
# Fetching comments for video hNTNZ00cZig (251/387)
# Fetching comments for video gz2j5NBESSs (252/387)
# Fetching comments for video opJgMj1IUrc (253/387)
# Fetching comments for video yRWkSKRYCaI (254/387)
# Fetching comments for video _jmiEGZ6PIY (255/387)
# Fetching comments for video 4A8LV6fObYA (256/387)
# Fetching comments for video MPENhkuSo0Q (257/387)
# Fetching comments for video 3irO29PJQHs (258/387)
# Fetching comments for video uHJFJUIYNAo (259/387)
# Fetching comments for video gMAHXrty6wI (260/387)
# Fetching comments for video BIUFr9srS78 (261/387)
# Fetching comments for video _eZRkmRfVTM (262/387)
# Fetching comments for video s3JmRxs53W4 (263/387)
# Fetching comments for video yDG5KiiOZcQ (264/387)
# Fetching comments for video Z7hPEwCzk2s (265/387)
# Fetching comments for video XRPyj7cKVsQ (266/387)
# Fetching comments for video lH7HfwUFnYA (267/387)
# Fetching comments for video zOR0-nygfDE (268/387)
# Fetching comments for video A4SVUF-fTwc (269/387)
# Fetching comments for video FnTunxd8tAM (270/387)
# Fetching comments for video -_z_aphWSEo (271/387)
# Fetching comments for video pL0jEjeM5hI (272/387)
# Fetching comments for video eg_5EAUXs5o (273/387)
# Fetching comments for video ebjDwX8sUMk (274/387)
# Fetching comments for video f6qxxtWkaUg (275/387)
# Fetching comments for video 6xv1KvCMF1Q (276/387)
# Fetching comments for video 465x3JmMJYU (277/387)
# Fetching comments for video Ns1ZpTxQnUE (278/387)
# Fetching comments for video HiOtQMcI5wg (279/387)
# Fetching comments for video CUa30M_FPhk (280/387)
# Fetching comments for video DKrSgSy6F1o (281/387)
# Fetching comments for video _zxPx1PQCqI (282/387)
# Fetching comments for video UGF49YZZRNc (283/387)
# Fetching comments for video aLp-6C-p-T0 (284/387)
# Fetching comments for video ocdwh0KYeUs (285/387)
# Fetching comments for video iPYVYBtUTyE (286/387)
# Fetching comments for video dMHWOhgzUhU (287/387)
# Fetching comments for video A-LkxegXFX8 (288/387)
# Fetching comments for video RJw-GSXXguA (289/387)
# Fetching comments for video 8rO7ztF4NtU (290/387)
# Fetching comments for video QILNlRvJlfQ (291/387)
# Fetching comments for video SVv0WwPzaUg (292/387)
# Fetching comments for video qfyynHBFOsM (293/387)
# Fetching comments for video m1KcNV-Zhmc (294/387)
# Fetching comments for video IZRe0nwkuXc (295/387)
# Fetching comments for video 9RRQtNnq3s0 (296/387)
# Fetching comments for video qewHAdfzLOw (297/387)
# Fetching comments for video bHssBHfHWmU (298/387)
# Fetching comments for video A4OVjWeVb10 (299/387)
# Fetching comments for video SIseim20_Dc (300/387)
# Fetching comments for video NrBJmtD0kEw (301/387)
# Fetching comments for video wnapnTAMj68 (302/387)
# Fetching comments for video duMcYRtQITA (303/387)
# Fetching comments for video QG1fo7LFesA (304/387)
# Fetching comments for video pYRG5X7110M (305/387)
# Fetching comments for video NViKsiGP4TY (306/387)
# Fetching comments for video 1gdKC5O0Pwc (307/387)
# Fetching comments for video GQj6_6V_jVA (308/387)
# Fetching comments for video RF0LE3hYFrI (309/387)
# Fetching comments for video 8o-O6pR6yAE (310/387)
# Fetching comments for video eFDbE5Yunj0 (311/387)
# Fetching comments for video D9bNctNnAig (312/387)
# Fetching comments for video VsztBAEtC7c (313/387)
# Fetching comments for video T3KMZoXrVTQ (314/387)
# Fetching comments for video tJaDicmRW7s (315/387)
# Fetching comments for video hfRcaRw_atI (316/387)
# Fetching comments for video aPDOGxrONy0 (317/387)
# Fetching comments for video w25ZjL0OqT4 (318/387)
# Fetching comments for video EWPeAXrF3zg (319/387)
# Fetching comments for video ru0Xdvxd37Q (320/387)
# Fetching comments for video BAVPAYWAoC4 (321/387)
# Fetching comments for video whgwEwA5SHU (322/387)
# Fetching comments for video K1WeoKxLZ5o (323/387)
# Fetching comments for video 0HRgbb1PcDQ (324/387)
# Fetching comments for video D6XNlTfglW4 (325/387)
# Fetching comments for video MQ5UUNjWgug (326/387)
# Fetching comments for video JikLVP9DkPs (327/387)
# Fetching comments for video yzqpYs7dIqY (328/387)
# Fetching comments for video 7uH7_DThtX0 (329/387)
# Fetching comments for video GGLF2jLo8J4 (330/387)
# Fetching comments for video BGBXnNvWdQ4 (331/387)
# Fetching comments for video PurMLMKNX0I (332/387)
# Fetching comments for video pvxNYyJuiqA (333/387)
# Fetching comments for video rZpfNh28nFI (334/387)
# Fetching comments for video brxnKIy6Cek (335/387)
# Fetching comments for video ySq0cgkZiX4 (336/387)
# Fetching comments for video aJ9Q10v8Nrc (337/387)
# Fetching comments for video C2ik_qR5GOU (338/387)
# Fetching comments for video mLUzFXPPa4I (339/387)
# Fetching comments for video XmFhpoS6Etk (340/387)
# Fetching comments for video 1xT68oeQTd0 (341/387)
# Fetching comments for video eTsHJoMmhYQ (342/387)
# Fetching comments for video 8SolrjsGqzE (343/387)
# Fetching comments for video SKsjWzzz4mY (344/387)
# Fetching comments for video Z2AachB309o (345/387)
# Fetching comments for video _gP-DH0iZLw (346/387)
# Fetching comments for video -Inc1be4zSg (347/387)
# Fetching comments for video CsMh7Ykmnw4 (348/387)
# Fetching comments for video ho2vzKPAD50 (349/387)
# Fetching comments for video 5MZo2RoS8Yo (350/387)
# Fetching comments for video M2ySRYpo9S0 (351/387)
# Fetching comments for video ncXgqGePvwI (352/387)
# Fetching comments for video ywZXpfdqg1o (353/387)
# Fetching comments for video IqQCBytyATo (354/387)
# Fetching comments for video MpIi4HtCiVk (355/387)
# Fetching comments for video G4syHs3M82E (356/387)
# Fetching comments for video appOFpF2pFg (357/387)
# Fetching comments for video B2SPC3Wz1R8 (358/387)
# Fetching comments for video fUpChfNN5Uo (359/387)
# Fetching comments for video Dk7he_yEs4U (360/387)
# Fetching comments for video LJtFgnHGAos (361/387)
# Fetching comments for video ziurEoqEcO4 (362/387)
# Fetching comments for video rLKC--8UYSw (363/387)
# Fetching comments for video sua7xKN0cPc (364/387)
# Fetching comments for video fweZQqB0nwQ (365/387)
# Fetching comments for video oXAwKZWfbW0 (366/387)
# Fetching comments for video bhnrIforc7s (367/387)
# Fetching comments for video tYBOMw7Ob8E (368/387)
# Fetching comments for video Twusw__OzA8 (369/387)
# Fetching comments for video lYKkro6rKm0 (370/387)
# Fetching comments for video 9URM1_2S0ho (371/387)
# Fetching comments for video qzZU6LAtIig (372/387)
# Fetching comments for video LXwfzIRD-Ds (373/387)
# Fetching comments for video A9TOuDZTPDU (374/387)
# Fetching comments for video PyYgERKq25I (375/387)
# Fetching comments for video RSlqWnP-Dy8 (376/387)
# Fetching comments for video 9o9loJpG-t4 (377/387)
# Fetching comments for video Lacbh0VoT3g (378/387)
# Fetching comments for video oZKs2xMbXQE (379/387)
# Fetching comments for video N8f7NtDpbxA (380/387)
# Fetching comments for video wcKzdRVsMOw (381/387)
# Fetching comments for video Ns-8Jsa3mEM (382/387)
# Fetching comments for video 4rfr6A3lO-Y (383/387)
# Fetching comments for video OTq2NRy_AGs (384/387)
# Fetching comments for video ya28cb3zFGE (385/387)
# Fetching comments for video Hsi2BG0SOiQ (386/387)
# Fetching comments for video 6lQzbk6_OTw (387/387)
# Comments extraction completed!
